# %%
from PIL import Image

# %%
first = Image.open('word_matrix.png')

# %%
second = Image.open("mask.png")

# %%
first.size
# Out:
# (1015, 559)

# %%
second.size
# Out:
# (505, 251)

# %%
x = 0
y = 0

w = 1015

h = 559


second = second.resize((1015,559))

# %%
first
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x2623D5A1760>

# %%
second
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x2623C40F970>

# %%
second.putalpha(200)

# %%
#  first.putalpha(157)

# %%
first
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x2623D5A1760>

# %%
second
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x2623C40F970>

# %%
second.paste(first,box=(0,0),mask=first)

# %%
first.paste(second,(0,0),second)

# %%
second
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x2623C40F970>

# %%
first
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x2623D5A1760>

# %%
stop fight great hike brave sow late quote
# Out:
#   Input In [16]
#     stop fight great hike brave sow late quote
#          ^
# SyntaxError: invalid syntax

# %%
you great are work the with images best
